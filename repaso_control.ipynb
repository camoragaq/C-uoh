# %% [markdown]
# <a href="https://colab.research.google.com/github/camoragaq/C-uoh/blob/main/repaso_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Repaso para primer Control Cátedra

# %% [markdown]
# 1. Haga una función en C que reciba un número variable tipo int y devuelva su composición a número binario.

# %%
# %%writefile ej1.c
# #include <stdio.h>
#
# void getbinary(int n)
# {
#
# }
#
# int main()
# {
# 	int num=0;
# 	printf("Ingrese un número entero :");
# 	scanf("%d",&num);
# 	printf("\nel valor binario de %d es =",num);
# 	getbinary(num);
# 	return 0;
# }
# Out:
# Overwriting ej1.c

# %%
# %%script bash
#
# gcc ej1.c -o ej1

# %%
# !./ej1
# Out:
# Ingrese un número entero :3
# 0000000000000011
# el valor binario de 3 es =

# %% [markdown]
# 2. Escriba una función en C que retorne el número mínimo de bits necesarios para almacenar un entero.

# %%
# %%writefile ej2.c
#
# #include <stdio.h>
#
# int cuentabit(int n)
# {
#
# }
#
# int main()
# {
# 	int num;
# 	printf("Ingresa un numero entero :");
# 	scanf("%d",&num);
#
# 	printf("Total de numeros requeridos = %d\n",cuentabit(num));
# 	return 0;
# }
# Out:
# Writing ej2.c

# %%
# %%script bash
#
# gcc ej2.c -o ej2

# %%
# !./ej2
# Out:
# Ingresa un numero entero :3
# Total de numeros requeridos = 2

# %% [markdown]
# 3. Usando punteros escriba una función que intercambie 2 variables.

# %%
# %%writefile ej3.c
#
#
# #include <stdio.h>
#
# void swap(int* a, int* b)
# {
#     ...
# }
#
# int main()
# {
#     int a, b;
#
#     printf("Ingrese el primer numero: ");
#     scanf("%d", &a);
#     printf("Ingrese el segundo numero: ");
#     scanf("%d", &b);
#
#     printf("Originalmente: a=%d, b=%d\n", a, b);
#     swap(&a, &b);
#     printf("Intercambiamos:  a=%d, b=%d\n", a, b);
#
#     return 0;
# }
# Out:
# Overwriting ej3.c

# %%
# %%script bash
#
# gcc ej3.c -o ej3

# %%
# !./ej3
# Out:
# Ingrese el primer numero: 3
# Ingrese el segundo numero: 5
# Originalmente: a=3, b=5
# Intercambiamos:  a=5, b=3

# %% [markdown]
# 4. Según las siguientes definiciones, ejemplifique como quedaría la memoria.

# %% [markdown]
# ![Screenshot 2022-09-26 at 11.09.37.png](data:image/png;base64,...)

# %%
# %%writefile ej4.c
#
# #include <stdio.h>
#
# ...

# %% [markdown]
# 5. Usando punteros, estructuras y asignación de memoria dinámica, cree un programa que agregue personas a la siguiente estructura ya definida:

# %%
#include <stdio.h>
#include <stdlib.h>
struct persona {
   int edad;
   float peso;
   char nombre[30];
};

# %% [markdown]
# 6. Identifique el error:

# %%
# %%writefile intfunc.c
#
# #include <stdio.h>
#
# int int_size(){
#     int i=~0;
#     int size=0;
#     while(i){
#        size++;
#        i=i>>1;
#     }
#     return size;
#
# }
#
# int main(){
#     printf("La variable tipo int en esta máquina tiene %d bits.\n", int_size());
#     return 0;
# }

# %% [markdown]
# 7. Siguiendo el siguiente código:

# %%
#include <stdio.h>
int main()
{
   int* pc, c;
   
   c = 22;
   printf("Address of c: %p\n", &c);
   printf("Value of c: %d\n\n", c); 
   
   pc = &c;
   printf("Address of pointer pc: %p\n", pc);
   printf("Content of pointer pc: %d\n\n", *pc);
   
   c = 11;
   printf("Address of pointer pc: %p\n", pc);
   printf("Content of pointer pc: %d\n\n", *pc);
   
   *pc = 2;
   printf("Address of c: %p\n", &c);
   printf("Value of c: %d\n\n", c);
   return 0;
}

# %% [markdown]
# Cual será el valor de &pc, pc y *pc?

# %% [markdown]
# 8. Dado el siguiente código usando estructuras, cree una función en C que agregue personas usando la funcion scanf().

# %%
#include <stdio.h>
#include <string.h>


struct persona {
  char nombre[50];
  int rut;
  float salario;
} Pp;

int main() {
  

  return 0;
}

# %% [markdown]
# 8. Cree una lista enlazada que contenga los siguientes alumnos:
#
# juan->carol->valeria->luis->Lucas->NULL
#
# Debe eleminar del ramo a la alumna "valeria", y además agregar el alumno nuevo "Emilia".
